# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from Source.eda import *

import re
import warnings
warnings.filterwarnings('ignore')

# %%
sheet_names= ['loan_information', 'Employment','Personal_information', 'Other_information' ]

data = pd.read_excel('inputs/Credit_Risk_Dataset.xlsx', sheet_names)

# %%
loan_information = data['loan_information']
employment = data['Employment']
personal_information = data['Personal_information']
other_information = data['Other_information']

# %%
loan_information.head()
# Out:
#    User_id  Loan Category   Amount  Interest Rate  Tenure(years)
# 0  7013527  Consolidation  55884.0          11.84              6
# 1  7014291  Consolidation  55511.0          16.94              4
# 2  7014327  Consolidation  12289.0          11.84              6
# 3  7014304    Credit Card  29324.0          14.71              4
# 4  7031995    Credit Card  30252.0          14.71              4

# %%
data_nan = (loan_information.isnull().sum() / len(loan_information)) * 100
data_nan = data_nan.drop(data_nan[data_nan == 0].index).sort_values(ascending=False)[:10]
missing_data = pd.DataFrame({'Missing Ratio' :data_nan})
missing_data.head(5)
# Out:
#         Missing Ratio
# Amount      20.547252

# %%
f, ax = plt.subplots(figsize=(7, 5))
plt.xticks(rotation='vertical')
sns.barplot(x=data_nan.index, y=data_nan)
plt.xlabel('Features ', fontsize=10)
plt.ylabel('Percent of missing features values', fontsize=10)
plt.title('Percent missing data by feature in loan information dataset', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature in loan information dataset')

# %%
employment.head()
# Out:
#    User id    Employmet type Tier of Employment  \
# 0  7013527          Salaried                  B
# 1  7014291  Self - Employeed                  D
# 2  7014327               NaN                NaN
# 3  7014304               NaN                NaN
# 4  7031995               NaN                NaN
#
#                                             Industry  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 2  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 3  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 4  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
#
#                                Role Work Experience  Total Income(PA)
# 0  KHMbckjadbckIFGAZSEWdkcndwkcnCCM             1-2          125000.0
# 1  KHMbckjadbckIFGNCSEWdkcndwkcnCCM             10+           61000.0
# 2  KHMbckjadbckIFGNYSEWdkcndwkcnCCM            5-10          100000.0
# 3  KHMbckjadbckIFGCASEWdkcndwkcnCCM             2-3           30000.0
# 4  KHMbckjadbckIFGCASEWdkcndwkcnCCM             10+           65000.0

# %%
data_nan = (employment.isnull().sum() / len(employment)) * 100
data_nan = data_nan.drop(data_nan[data_nan == 0].index).sort_values(ascending=False)[:10]
missing_data = pd.DataFrame({'Missing Ratio' :data_nan})
missing_data.head(5)
# Out:
#                     Missing Ratio
# Employmet type          59.282680
# Tier of Employment      59.282680
# Industry                 0.002976
# Work Experience          0.002976

# %%
f, ax = plt.subplots(figsize=(7, 5))
plt.xticks(rotation='vertical')
sns.barplot(x=data_nan.index, y=data_nan, palette=("Accent"))
plt.xlabel('Features ', fontsize=10)
plt.ylabel('Percent of missing features values', fontsize=10)
plt.title('Percent missing data by feature in employment dataset', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature in employment dataset')

# %%
personal_information.head()
# Out:
#    User id  Gender Married  Dependents      Home Pincode Social Profile  \
# 0  7013527  Female     Yes           4      rent  XX852X             No
# 1  7014291  Female      No           1  mortgage  XX286X            NaN
# 2  7014327   Other     NaN           3       own  XX113X             No
# 3  7014304    Male     NaN           1      rent  XX941X            Yes
# 4  7031995    Male     NaN           3      rent  XX913X             No
#
#        Is_verified
# 0              NaN
# 1  Source Verified
# 2              NaN
# 3              NaN
# 4         Verified

# %%
data_nan = (personal_information.isnull().sum() / len(personal_information)) * 100
data_nan = data_nan.drop(data_nan[data_nan == 0].index).sort_values(ascending=False)[:10]
missing_data = pd.DataFrame({'Missing Ratio' :data_nan})
missing_data.head(5)
# Out:
#                 Missing Ratio
# Married             33.540400
# Social Profile      33.363339
# Is_verified         24.927651

# %%
f, ax = plt.subplots(figsize=(7, 5))
plt.xticks(rotation='vertical')
sns.barplot(x=data_nan.index, y=data_nan, palette=("Accent"))
plt.xlabel('Features ', fontsize=10)
plt.ylabel('Percent of missing features values', fontsize=10)
plt.title('Percent missing data by feature in personal information dataset', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature in personal information dataset')

# %%
other_information.head()
# Out:
#    User_id  Delinq_2yrs  Total Payement   Received Principal  \
# 0  7013527            0      1824.150000              971.46
# 1  7014291            0     22912.532998            18000.00
# 2  7014327            0      7800.440000             4489.76
# 3  7014304            0      6672.050000             5212.29
# 4  7031995            0     11793.001345            10000.00
#
#    Interest Received  Number of loans  Defaulter
# 0             852.69                0          1
# 1            4912.53                0          0
# 2            3310.68                0          1
# 3            1459.76                0          0
# 4            1793.00                0          0

# %%
data_nan = (other_information.isnull().sum() / len(other_information)) * 100
data_nan = data_nan.drop(data_nan[data_nan == 0].index).sort_values(ascending=False)[:10]
missing_data = pd.DataFrame({'Missing Ratio' :data_nan})
missing_data.head(5)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
data = pd.merge(loan_information, employment, left_on = 'User_id', right_on = 'User id')
data = data.drop(['User_id'], axis=1)
data.head()
# Out:
#    Loan Category   Amount  Interest Rate  Tenure(years)  User id  \
# 0  Consolidation  55884.0          11.84              6  7013527
# 1  Consolidation  55511.0          16.94              4  7014291
# 2  Consolidation  12289.0          11.84              6  7014327
# 3    Credit Card  29324.0          14.71              4  7014304
# 4    Credit Card  30252.0          14.71              4  7031995
#
#      Employmet type Tier of Employment  \
# 0          Salaried                  B
# 1  Self - Employeed                  D
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
#
#                                             Industry  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 2  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 3  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 4  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
#
#                                Role Work Experience  Total Income(PA)
# 0  KHMbckjadbckIFGAZSEWdkcndwkcnCCM             1-2          125000.0
# 1  KHMbckjadbckIFGNCSEWdkcndwkcnCCM             10+           61000.0
# 2  KHMbckjadbckIFGNYSEWdkcndwkcnCCM            5-10          100000.0
# 3  KHMbckjadbckIFGCASEWdkcndwkcnCCM             2-3           30000.0
# 4  KHMbckjadbckIFGCASEWdkcndwkcnCCM             10+           65000.0

# %%
data = pd.merge(data, personal_information, left_on = 'User id', right_on = 'User id')
data = pd.merge(data, other_information, left_on = 'User id', right_on = 'User_id')
data = data.drop(['User_id'], axis=1)
print('Number of rows {} and number of features {}'.format(data.shape[0], data.shape[1]))
# Out:
# Number of rows 143727 and number of features 24

# %%
data.head()
# Out:
#    Loan Category   Amount  Interest Rate  Tenure(years)  User id  \
# 0  Consolidation  55884.0          11.84              6  7013527
# 1  Consolidation  55511.0          16.94              4  7014291
# 2  Consolidation  12289.0          11.84              6  7014327
# 3    Credit Card  29324.0          14.71              4  7014304
# 4    Credit Card  30252.0          14.71              4  7031995
#
#      Employmet type Tier of Employment  \
# 0          Salaried                  B
# 1  Self - Employeed                  D
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
#
#                                             Industry  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 2  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 3  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 4  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
#
#                                Role Work Experience  ...  Pincode  \
# 0  KHMbckjadbckIFGAZSEWdkcndwkcnCCM             1-2  ...   XX852X
# 1  KHMbckjadbckIFGNCSEWdkcndwkcnCCM             10+  ...   XX286X
# 2  KHMbckjadbckIFGNYSEWdkcndwkcnCCM            5-10  ...   XX113X
# 3  KHMbckjadbckIFGCASEWdkcndwkcnCCM             2-3  ...   XX941X
# 4  KHMbckjadbckIFGCASEWdkcndwkcnCCM             10+  ...   XX913X
#
#   Social Profile      Is_verified  User_id Delinq_2yrs Total Payement   \
# 0             No              NaN  7013527           0     1824.150000
# 1            NaN  Source Verified  7014291           0    22912.532998
# 2             No              NaN  7014327           0     7800.440000
# 3            Yes              NaN  7014304           0     6672.050000
# 4             No         Verified  7031995           0    11793.001345
#
#   Received Principal Interest Received  Number of loans  Defaulter
# 0             971.46            852.69                0          1
# 1           18000.00           4912.53                0          0
# 2            4489.76           3310.68                0          1
# 3            5212.29           1459.76                0          0
# 4           10000.00           1793.00                0          0
#
# [5 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['Loan Category', 'Amount', 'Interest Rate', 'Tenure(years)', 'User id',
#        'Employmet type', 'Tier of Employment', 'Industry', 'Role',
#        'Work Experience', 'Total Income(PA)', 'Gender', 'Married',
#        'Dependents', 'Home', 'Pincode', 'Social Profile', 'Is_verified',
#        'Delinq_2yrs', 'Total Payement ', 'Received Principal',
#        'Interest Received', 'Number of loans', 'Defaulter'],
#       dtype='object')

# %%
data_nan = (data.isnull().sum() / len(data)) * 100
data_nan = data_nan.drop(data_nan[data_nan == 0].index).sort_values(ascending=False)[:10]
missing_data = pd.DataFrame({'Missing Ratio' :data_nan})
missing_data.head(5)
# Out:
#                     Missing Ratio
# Employmet type          58.890814
# Tier of Employment      58.890814
# Married                 33.496142
# Social Profile          33.296458
# Is_verified             24.910420

# %%
f, ax = plt.subplots(figsize=(7, 5))
plt.xticks(rotation='vertical')
sns.barplot(x=data_nan.index, y=data_nan, palette=("Accent"))
plt.xlabel('Features ', fontsize=10)
plt.ylabel('Percent of missing features values', fontsize=10)
plt.title('Percent missing data by feature in dataset', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature in dataset')

# %%
# Drop rows with missing values in the 'Industry' and 'Work Experience' columns as the data in 'Industry' is meaningless due to encryption, and 'Work Experience' is inconsistent in the dataset, treating it as an object datatype variable which may impact model performance.
data = data.dropna(subset=['Industry', 'Role', "User id","User_id", "Pincode", ], axis=1, )

# %%
data["Pincode"].unique()
# Out:
# array(['XX852X', 'XX286X', 'XX113X', 'XX941X', 'XX913X', 'XX152X',
#        'XX933X', 'XX441X', 'XX900X', 'XX812X', 'XX480X', 'XX761X',
#        'XX850X', 'XX983X', 'XX226X', 'XX606X', 'XX112X', 'XX242X',
#        'XX723X', 'XX917X', 'XX110X', 'XX748X', 'XX857X', 'XX73X',
#        'XX315X', 'XX891X', 'XX750X', 'XX944X', 'XX190X', 'XX71X',
#        'XX935X', 'XX281X', 'XX322X', 'XX172X', 'XX456X', 'XX77X',
#        'XX337X', 'XX600X', 'XX956X', 'XX919X', 'XX986X', 'XX457X',
#        'XX802X', 'XX906X', 'XX607X', 'XX974X', 'XX207X', 'XX910X',
#        'XX810X', 'XX74X', 'XX951X', 'XX920X', 'XX238X', 'XX125X',
#        'XX433X', 'XX495X', 'XX302X', 'XX130X', 'XX199X', 'XX902X',
#        'XX540X', 'XX54X', 'XX50X', 'XX182X', 'XX53X', 'XX728X', 'XX955X',
#        'XX768X', 'XX637X', 'XX400X', 'XX655X', 'XX422X', 'XX364X',
#        'XX737X', 'XX676X', 'XX44X', 'XX677X', 'XX881X', 'XX623X',
#        'XX157X', 'XX590X', 'XX898X', 'XX169X', 'XX249X', 'XX673X',
#        'XX636X', 'XX795X', 'XX619X', 'XX466X', 'XX174X', 'XX710X',
#        'XX736X', 'XX738X', 'XX713X', 'XX877X', 'XX499X', 'XX411X',
#        'XX635X', 'XX994X', 'XX417X', 'XX828X', 'XX256X', 'XX646X',
#        'XX409X', 'XX369X', 'XX592X', 'XX538X', 'XX445X', 'XX679X',
#        'XX413X', 'XX593X', 'XX669X', 'XX424X', 'XX746X', 'XX102X',
#        'XX879X', 'XX438X', 'XX969X', 'XX831X', 'XX556X', 'XX267X',
#        'XX149X', 'XX408X', 'XX84X', 'XX96X', 'XX135X', 'XX595X', 'XX822X',
#        'XX821X', 'XX395X', 'XX749X', 'XX259X', 'XX372X', 'XX639X',
#        'XX576X', 'XX332X', 'XX792X', 'XX340X', 'XX394X', 'XX878X',
#        'XX392X', 'XX397X', 'XX379X', 'XX373X', 'XX377X', 'XX378X',
#        'XX381X', 'XX396X', 'XX663X', 'XX390X', 'XX380X', 'XX374X',
#        'XX383X', 'XX386X', 'XX384X', 'XX371X', 'XX376X', 'XX385X',
#        'XX475X', 'XX388X', 'XX391X', 'XX747X', 'XX382X', 'XX387X',
#        'XX470X', 'XX393X', 'XX389X', 'XX94X', 'XX91X', 'XX500X', 'XX429X',
#        'XX962X', 'XX311X', 'XX681X', 'XX59X', 'XX854X', 'XX836X',
#        'XX414X', 'XX582X', 'XX7X', 'XX90X', 'XX929X', 'XX942X', 'XX523X'],
#       dtype=object)

# %%
data.dtypes
# Out:
# Loan Category          object
# Amount                float64
# Interest Rate         float64
# Tenure(years)           int64
# User id                 int64
# Employmet type         object
# Tier of Employment     object
# Industry               object
# Role                   object
# Work Experience        object
# Total Income(PA)      float64
# Gender                 object
# Married                object
# Dependents              int64
# Home                   object
# Pincode                object
# Social Profile         object
# Is_verified            object
# User_id                 int64
# Delinq_2yrs             int64
# Total Payement        float64
# Received Principal    float64
# Interest Received     float64
# Number of loans         int64
# Defaulter               int64
# dtype: object

# %%
data.describe()
# Out:
#              Amount  Interest Rate  Tenure(years)       User id  \
# count  1.118030e+05  143727.000000  143727.000000  1.437270e+05
# mean   1.376458e+05      12.038703       4.514503  3.733474e+07
# std    1.575427e+05       3.880204       0.874241  3.182811e+07
# min    0.000000e+00       5.420000       4.000000  2.080360e+05
# 25%    2.837950e+04       9.180000       4.000000  3.276118e+06
# 50%    7.660300e+04      11.840000       4.000000  5.766517e+07
# 75%    2.054645e+05      14.440000       6.000000  6.729174e+07
# max    8.000078e+06      23.540000       6.000000  7.895894e+07
#
#        Total Income(PA)     Dependents       User_id    Delinq_2yrs  \
# count      1.437270e+05  143727.000000  1.437270e+05  143727.000000
# mean       7.242256e+04       1.997113  3.733474e+07       0.276601
# std        5.539328e+04       1.411317  3.182811e+07       0.789019
# min        4.000000e+03       0.000000  2.080360e+05       0.000000
# 25%        4.500000e+04       1.000000  3.276118e+06       0.000000
# 50%        6.180000e+04       2.000000  5.766517e+07       0.000000
# 75%        8.600000e+04       3.000000  6.729174e+07       0.000000
# max        7.141778e+06       4.000000  7.895894e+07      22.000000
#
#        Total Payement   Received Principal  Interest Received  \
# count    143727.000000       143727.000000      143727.000000
# mean      10840.882025         8407.001538        2352.729746
# std        8613.421536         7224.396032        2447.759754
# min           0.000000            0.000000           0.000000
# 25%        4674.775000         3104.160000         841.685000
# 50%        8212.410000         6000.000000        1632.240000
# 75%       14175.769677        11664.365000        2904.770000
# max       57777.579870        35000.010000       24205.620000
#
#        Number of loans      Defaulter
# count    143727.000000  143727.000000
# mean          0.005573       0.093712
# std           0.098785       0.291429
# min           0.000000       0.000000
# 25%           0.000000       0.000000
# 50%           0.000000       0.000000
# 75%           0.000000       0.000000
# max           5.000000       1.000000

# %%
data['Industry'].nunique()
# Out:
# 12974

# %%
# Call the function to print the number of unique values in all columns
unique_values_each_column(data)
# Out:
# Loan Category : 7
# Amount : 86157
# Interest Rate : 137
# Tenure(years) : 2
# User id : 133752
# Employmet type : 2
# Tier of Employment : 7
# Industry : 12974
# Role : 46
# Work Experience : 7
# Total Income(PA) : 11380
# Gender : 3
# Married : 2
# Dependents : 5
# Home : 5
# Pincode : 844
# Social Profile : 2
# Is_verified : 3
# User_id : 133752
# Delinq_2yrs : 22
# Total Payement  : 104202
# Received Principal : 42022
# Interest Received : 93862
# Number of loans : 5
# Defaulter : 2

# %%
def perc_on_bar(x):
    total_len = len(data[x]) # length of the column
    plt.figure(figsize=(15,7))
    ax = sns.countplot(x = data[x],palette='Paired')
    for p in ax.patches:
        per = '{:.1f}%'.format(100 * p.get_height()/total_len) 
        x = p.get_x() + p.get_width() / 2 - 0.10
        y = p.get_y() + p.get_height()          
        ax.annotate(per, (x, y), size = 12) # annotate the percantage 
    plt.show() # show the plot

# %%
perc_on_bar('Loan Category')

# %%
perc_on_bar('Defaulter')

# %%
perc_on_bar('Employmet type')

# %%
perc_on_bar('Tier of Employment')

# %%
perc_on_bar('Gender')

# %%
# Call the function to replace null values with "missing"
replace_with='missing'
columns_to_replace = ['Social Profile', 'Is_verified', 'Married', 'Employmet type']


data = replace_null_values_with_a_value(data, columns_to_replace, replace_with)

# %%
sns.FacetGrid(data).map(sns.kdeplot,"Amount").add_legend();
plt.show()

# %%
#property area 2000 3200
def avg_property_area(x):
    x = numbers.findall(x)
    if len(x) == 1:
        return np.float16(x[0])
    elif len(x) == 2:
        return (np.float16(x[0])+np.float16(x[1]))/2
    else:
        return 0
    
numbers = re.compile(r"[-+]?(\d*\.\d+|\d+)")     
data['Work Experience'] = data['Work Experience'].apply(lambda x: avg_property_area(str(x)))

# %%
perc_on_bar('Work Experience')

# %%
# Multicollinarity is the occurrence of high intercorrelations among two or more independent variables in a multiple regression mode

correlation_heatmap(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Multicollinarity is the occurrence of high intercorrelations among two or more independent variables in a multiple regression mode
# ----> 3 correlation_heatmap(data)
#
# File ~/Desktop/Project/Loan Default Prediction/Source/eda.py:43, in correlation_heatmap(train)
#      42 def correlation_heatmap(train):
# ---> 43     correlations = train.corr(method='spearman')
#      45     fig, ax = plt.subplots(figsize=(10, 10))
#      46     sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f',
#      47                 square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Consolidation'

# %%
data_final = data.drop(["Gender", "Married", "Home", "Social Profile", "Loan Category", "Employmet type", "Loan Category"], axis=1)
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 10))
mask = np.triu(np.ones_like(data.corr()))
sns.heatmap(data_final.corr(),cmap="YlGnBu", annot=True, mask=mask)
ax.set_title('Correlation Matrix', fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 3
#       1 data_final = data.drop(["Gender", "Married", "Home", "Social Profile", "Loan Category", "Employmet type", "Loan Category"], axis=1)
#       2 f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 10))
# ----> 3 mask = np.triu(np.ones_like(data.corr()))
#       4 sns.heatmap(data_final.corr(),cmap="YlGnBu", annot=True, mask=mask)
#       5 ax.set_title('Correlation Matrix', fontsize=16)
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~/PycharmProjects/environment/Loan Default Prediction/lib/python3.10/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Consolidation'

# %%
import pandas as pd

# Add all categorical features for categorical one-hot encoding in categorical_features array
categorical_features= ["Gender", "Married", "Home", "Social Profile", "Loan Category", "Employmet type","Is_verified"]

# Perform one-hot encoding using pandas get_dummies() function
encoded_data = pd.get_dummies(data, columns=categorical_features)

# %%
encoded_data.head()
# Out:
#     Amount  Interest Rate  Tenure(years)  User id Tier of Employment  \
# 0  55884.0          11.84              6  7013527                  B
# 1  55511.0          16.94              4  7014291                  D
# 2  12289.0          11.84              6  7014327                NaN
# 3  29324.0          14.71              4  7014304                NaN
# 4  30252.0          14.71              4  7031995                NaN
#
#                                             Industry  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 2  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 3  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 4  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
#
#                                Role  Work Experience  Total Income(PA)  \
# 0  KHMbckjadbckIFGAZSEWdkcndwkcnCCM              1.5          125000.0
# 1  KHMbckjadbckIFGNCSEWdkcndwkcnCCM             10.0           61000.0
# 2  KHMbckjadbckIFGNYSEWdkcndwkcnCCM              7.5          100000.0
# 3  KHMbckjadbckIFGCASEWdkcndwkcnCCM              2.5           30000.0
# 4  KHMbckjadbckIFGCASEWdkcndwkcnCCM             10.0           65000.0
#
#    Dependents  ... Loan Category_Home  Loan Category_Medical   \
# 0           4  ...              False                   False
# 1           1  ...              False                   False
# 2           3  ...              False                   False
# 3           1  ...              False                   False
# 4           3  ...              False                   False
#
#    Loan Category_Other   Employmet type_Salaried  \
# 0                 False                     True
# 1                 False                    False
# 2                 False                    False
# 3                 False                    False
# 4                 False                    False
#
#    Employmet type_Self - Employeed  Employmet type_missing  \
# 0                            False                   False
# 1                             True                   False
# 2                            False                    True
# 3                            False                    True
# 4                            False                    True
#
#    Is_verified_Not Verified  Is_verified_Source Verified  \
# 0                     False                        False
# 1                     False                         True
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    Is_verified_Verified  Is_verified_missing
# 0                 False                 True
# 1                 False                False
# 2                 False                 True
# 3                 False                 True
# 4                  True                False
#
# [5 rows x 45 columns]
